# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/20.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/6.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/5.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/8.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/10.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/0.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/9.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/1.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/29.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/16.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/23.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/7.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/28.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/22.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/24.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/13.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/17.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/26.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/15.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/12.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/11.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/27.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/21.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/4.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/3.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/19.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/14.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/18.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/2.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/pepsi/25.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/20.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/6.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/5.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/8.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/10.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/0.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/9.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/1.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/29.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/16.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/23.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/7.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/28.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/22.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/24.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/13.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/17.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/26.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/15.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/12.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/11.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/27.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/21.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/4.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/3.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/19.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/14.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/18.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/2.jpg
# /kaggle/input/pepsi-and-cocacola-images/test/cocacola/25.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/45.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/56.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/89.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/58.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/150.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/109.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/149.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/187.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/76.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/71.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/182.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/185.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/153.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/189.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/143.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/115.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/131.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/151.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/84.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/85.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/67.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/118.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/82.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/176.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/30.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/97.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/106.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/163.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/113.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/160.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/38.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/42.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/197.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/33.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/178.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/54.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/130.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/62.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/156.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/120.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/35.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/61.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/190.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/124.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/191.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/59.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/73.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/188.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/98.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/41.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/123.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/94.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/60.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/167.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/57.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/112.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/193.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/152.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/192.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/91.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/101.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/99.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/37.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/177.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/186.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/69.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/75.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/117.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/81.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/46.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/137.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/44.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/65.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/50.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/127.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/196.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/140.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/79.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/179.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/105.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/111.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/55.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/145.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/135.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/77.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/166.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/80.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/159.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/121.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/173.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/171.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/103.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/174.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/40.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/199.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/126.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/142.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/48.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/169.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/194.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/180.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/104.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/155.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/88.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/64.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/158.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/148.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/168.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/31.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/195.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/114.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/43.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/138.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/100.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/74.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/68.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/53.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/83.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/107.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/154.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/164.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/146.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/161.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/198.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/72.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/139.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/32.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/102.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/157.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/183.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/39.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/86.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/119.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/165.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/141.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/92.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/122.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/70.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/181.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/34.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/51.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/132.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/52.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/184.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/125.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/128.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/172.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/95.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/36.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/96.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/144.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/110.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/63.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/162.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/87.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/47.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/93.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/170.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/175.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/116.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/78.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/108.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/49.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/66.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/129.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/133.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/134.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/136.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/90.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/pepsi/147.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/45.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/56.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/89.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/58.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/150.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/109.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/149.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/187.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/76.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/71.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/182.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/185.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/153.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/189.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/143.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/115.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/131.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/151.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/84.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/85.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/67.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/118.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/82.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/176.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/30.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/97.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/106.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/163.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/113.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/160.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/38.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/42.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/197.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/33.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/178.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/54.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/130.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/62.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/156.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/120.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/35.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/61.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/190.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/124.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/191.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/59.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/73.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/188.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/98.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/41.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/123.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/94.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/60.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/167.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/57.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/112.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/193.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/152.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/192.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/91.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/101.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/99.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/37.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/177.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/186.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/69.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/75.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/117.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/81.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/46.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/137.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/44.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/65.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/50.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/127.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/196.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/140.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/79.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/179.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/105.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/111.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/55.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/145.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/135.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/77.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/166.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/80.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/159.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/121.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/173.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/171.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/103.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/174.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/40.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/199.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/126.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/142.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/48.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/169.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/194.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/180.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/104.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/155.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/88.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/64.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/158.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/148.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/168.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/31.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/195.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/114.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/43.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/138.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/100.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/74.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/68.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/53.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/83.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/107.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/154.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/164.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/146.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/161.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/198.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/72.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/139.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/32.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/102.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/157.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/183.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/39.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/86.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/119.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/165.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/141.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/92.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/122.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/70.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/181.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/34.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/51.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/132.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/52.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/184.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/125.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/128.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/172.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/95.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/36.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/96.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/144.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/110.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/63.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/162.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/87.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/47.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/93.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/170.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/175.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/116.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/78.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/108.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/49.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/66.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/129.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/133.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/134.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/136.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/90.jpg
# /kaggle/input/pepsi-and-cocacola-images/train/cocacola/147.jpg

# %%
import cv2
import matplotlib.pyplot as plt
import pathlib, os, random
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.layers import BatchNormalization, Dense, Dropout, Flatten, MaxPooling2D, Conv2D, Activation
import matplotlib.pyplot as plt
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
datagen = ImageDataGenerator(rescale= 1.0 / 255)
batch_size = 32
img_height, img_width = 200, 200
input_shape = (img_height, img_height, 3)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  '../input/pepsi-and-cocacola-images/train',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_ds = tf.keras.utils.image_dataset_from_directory(
  '../input/pepsi-and-cocacola-images/test',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 340 files belonging to 2 classes.
# Using 272 files for training.
# 2022-08-18 20:14:01.821184: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Found 60 files belonging to 2 classes.
# Using 12 files for validation.

# %%
class_names = train_ds.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# 2022-08-18 20:14:02.111850: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
model = Sequential([
  data_augmentation,  
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),  
  layers.Flatten(),
  layers.Dense(128, activation='relu6'),
  layers.Dense(128, activation='relu6'),
  layers.Dense(64, activation='sigmoid'),
  layers.Dense(64, activation='tanh'),  
  layers.Dense(len(class_names))
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 200, 200, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 200, 200, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 200, 200, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 40000)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5120128
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 5,172,770
# Trainable params: 5,172,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=15
history = model.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 9/9 [==============================] - 5s 377ms/step - loss: 0.6807 - accuracy: 0.5294 - val_loss: 0.6212 - val_accuracy: 0.5833
# Epoch 2/15
# 9/9 [==============================] - 3s 346ms/step - loss: 0.5476 - accuracy: 0.7279 - val_loss: 0.3216 - val_accuracy: 0.8333
# Epoch 3/15
# 9/9 [==============================] - 3s 341ms/step - loss: 0.3464 - accuracy: 0.8603 - val_loss: 0.1459 - val_accuracy: 0.9167
# Epoch 4/15
# 9/9 [==============================] - 3s 353ms/step - loss: 0.2021 - accuracy: 0.9191 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 5/15
# 9/9 [==============================] - 3s 345ms/step - loss: 0.1150 - accuracy: 0.9522 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 6/15
# 9/9 [==============================] - 3s 345ms/step - loss: 0.0886 - accuracy: 0.9669 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 7/15
# 9/9 [==============================] - 4s 417ms/step - loss: 0.0649 - accuracy: 0.9743 - val_loss: 0.0527 - val_accuracy: 1.0000
# Epoch 8/15
# 9/9 [==============================] - 3s 342ms/step - loss: 0.0548 - accuracy: 0.9779 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 9/15
# 9/9 [==============================] - 3s 343ms/step - loss: 0.1153 - accuracy: 0.9522 - val_loss: 0.0630 - val_accuracy: 0.9167
# Epoch 10/15
# 9/9 [==============================] - 3s 339ms/step - loss: 0.0917 - accuracy: 0.9669 - val_loss: 0.1996 - val_accuracy: 0.9167
# Epoch 11/15
# 9/9 [==============================] - 3s 339ms/step - loss: 0.0485 - accuracy: 0.9853 - val_loss: 0.0980 - val_accuracy: 0.9167
# Epoch 12/15
# 9/9 [==============================] - 3s 347ms/step - loss: 0.0226 - accuracy: 0.9963 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 13/15
# 9/9 [==============================] - 3s 337ms/step - loss: 0.0375 - accuracy: 0.9853 - val_loss: 0.4701 - val_accuracy: 0.9167
# Epoch 14/15
# 9/9 [==============================] - 3s 342ms/step - loss: 0.0583 - accuracy: 0.9816 - val_loss: 0.0894 - val_accuracy: 0.9167
# Epoch 15/15
# 9/9 [==============================] - 4s 414ms/step - loss: 0.0434 - accuracy: 0.9890 - val_loss: 0.0076 - val_accuracy: 1.0000

# %%
model.evaluate(test_ds)
# Out:
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0076 - accuracy: 1.0000
# [0.007557092700153589, 1.0]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
soda_url = "https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fpics.me.me%2F%25C2%25BFa-qui%25C3%25A9n-conoces-que-se-tomar%25C3%25ADa-toda-esta-coca-cola-sin-57275529.png&f=1&nofb=1"
soda_path = tf.keras.utils.get_file('soda', origin=soda_url)

img = tf.keras.utils.load_img(
    soda_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Downloading data from https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fpics.me.me%2F%25C2%25BFa-qui%25C3%25A9n-conoces-que-se-tomar%25C3%25ADa-toda-esta-coca-cola-sin-57275529.png&f=1&nofb=1
#   98304/Unknown - 0s 4us/stepThis image most likely belongs to cocacola with a 99.78 percent confidence.
